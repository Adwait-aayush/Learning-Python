# %% [markdown]
# <a href="https://colab.research.google.com/github/Adwait-aayush/Learning-Python/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pandas is used for data processing
#pandas dataframe is a 2d tabular data structure with labelled axes

import pandas as pd;
import numpy as np;

# %%
from sklearn.datasets import fetch_california_housing
housing = fetch_california_housing()

# we are importing a dataset named fetch_california_housing from sklearn and then in the next step weassign the dataset to a variable called housing

# %%
print(type(housing))
# Out:
# <class 'sklearn.utils._bunch.Bunch'>

# %%
print(housing)
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#           37.88      , -122.23      ],
#        [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#           37.86      , -122.22      ],
#        [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#           37.85      , -122.24      ],
#        ...,
#        [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#           39.43      , -121.22      ],
#        [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#           39.43      , -121.32      ],
#        [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
# ...

# %%
df2=pd.DataFrame(housing.data,columns =housing.feature_names)
#the data provided above is very unorganized so what we have to do is convert it into a dataframe and we only want the data is the dataframe so we use housing.data and we want the labels or coloums so we use coloums=housing.feature this will assign the feature values of the housing data as labels of dataframe

# %%
df2.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
df.shape
# gives the rows and coloums
# Out:
# (20640, 8)

# %%
#importing data from csv file to a panda dataframe

data=pd.read_csv("/content/diabetes.csv")
df=pd.DataFrame(data)
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.to_csv('data')
#convert dataframe to a csv file

# %%
#dataframe with random values

random_df=pd.DataFrame(np.random.rand(20,10))
random_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.908053  0.360455  0.963262  0.080725  0.796881  0.445954  0.630664
# 1  0.434968  0.992362  0.969803  0.774715  0.435173  0.583709  0.411246
# 2  0.185842  0.787780  0.816080  0.024431  0.018476  0.045582  0.890526
# 3  0.882575  0.147535  0.164446  0.804699  0.116628  0.153096  0.450228
# 4  0.811221  0.296721  0.446322  0.851362  0.618652  0.749031  0.093832
#
#           7         8         9
# 0  0.557422  0.726280  0.545230
# 1  0.638619  0.922938  0.605747
# 2  0.297285  0.861118  0.962610
# 3  0.572579  0.203490  0.611759
# 4  0.491148  0.275223  0.829600

# %%
# inspecting a dataframe
#.shape function is used to display the rows and columns
#.head() gives first 5 rows by default  .tail() gives last 5 rows by default

# %%
# isnull function returns true is a value is null
df.isnull()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0          False    False          False          False    False  False
# 1          False    False          False          False    False  False
# 2          False    False          False          False    False  False
# 3          False    False          False          False    False  False
# 4          False    False          False          False    False  False
# ..           ...      ...            ...            ...      ...    ...
# 763        False    False          False          False    False  False
# 764        False    False          False          False    False  False
# 765        False    False          False          False    False  False
# 766        False    False          False          False    False  False
# 767        False    False          False          False    False  False
#
#      DiabetesPedigreeFunction    Age  Outcome
# 0                       False  False    False
# ...

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#counting  the  values based on the labels
df.value_counts('Outcome')
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
df.value_counts("Age")
# Out:
# Age
# 22    72
# 21    63
# 25    48
# 24    46
# 23    38
# 28    35
# 26    33
# 27    32
# 29    29
# 31    24
# 41    22
# 30    21
# 37    19
# 42    18
# 33    17
# 32    16
# 38    16
# 36    16
# 45    15
# 34    14
# 46    13
# 43    13
# 40    13
# 39    12
# 35    10
# 44     8
# 51     8
# 50     8
# 52     8
# 58     7
# 54     6
# 47     6
# 49     5
# 53     5
# 57     5
# 48     5
# 60     5
# 55     4
# 63     4
# 62     4
# 66     4
# 56     3
# 65     3
# 59     3
# 67     3
# 61     2
# 69     2
# 64     1
# 68     1
# 70     1
# 72     1
# 81     1
# Name: count, dtype: int64

# %%
# grouping by the labels

df.groupby('Age').mean()
# Out:
#      Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Age
# 21      1.079365  108.317460      65.936508      19.349206   73.634921
# 22      1.555556  108.208333      63.722222      20.486111   74.486111
# 23      1.578947  111.578947      64.315789      22.368421  118.026316
# 24      1.891304  117.891304      64.956522      25.934783   88.021739
# 25      1.770833  110.083333      59.666667      23.958333   82.895833
# 26      1.969697  118.212121      64.181818      23.666667   90.878788
# 27      2.562500  115.281250      73.500000      18.375000   63.125000
# 28      3.028571  119.914286      68.314286      23.628571   94.600000
# 29      3.310345  127.379310      68.241379      21.000000   88.793103
# 30      3.619048  122.285714      64.857143      18.904762   82.666667
# 31      3.875000  126.958333      64.375000      20.000000  111.166667
# 32      4.437500  116.312500      70.062500      18.187500   35.812500
# ...

# %%
#statistcal measures

df.count()
# Out:
# Pregnancies                 768
# Glucose                     768
# BloodPressure               768
# SkinThickness               768
# Insulin                     768
# BMI                         768
# DiabetesPedigreeFunction    768
# Age                         768
# Outcome                     768
# dtype: int64

# %%
#mean value colums wise
df.mean()
# Out:
# Pregnancies                   3.845052
# Glucose                     120.894531
# BloodPressure                69.105469
# SkinThickness                20.536458
# Insulin                      79.799479
# BMI                          31.992578
# DiabetesPedigreeFunction      0.471876
# Age                          33.240885
# Outcome                       0.348958
# dtype: float64

# %%
# std-standard deviation
#min-minimum value for each coloums
#max- maximum ''

# %%
#describe is used to get all statistical measure coloum wise
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
#manipulating dataset

#adding coloumn

df2.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
df2['Price']=housing.target

# %%
df2.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  Price
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %%
#remove a row
#axis=0 for row 1 for coloums
#first value is index
df2.drop(0,axis=0)
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# 5      4.0368      52.0  4.761658   1.103627       413.0  2.139896     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  Price
# ...

# %%
df2.drop(columns='MedInc',axis=1)
# Out:
#        HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0          41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1          21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2          52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3          52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4          52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...         ...       ...        ...         ...       ...       ...
# 20635      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  Price
# 0        -122.23  4.526
# 1        -122.22  3.585
# 2        -122.24  3.521
# 3        -122.25  3.413
# ...

# %%
#iloc fn is used to search by index
df2.iloc[1]
# Out:
# MedInc           8.301400
# HouseAge        21.000000
# AveRooms         6.238137
# AveBedrms        0.971880
# Population    2401.000000
# AveOccup         2.109842
# Latitude        37.860000
# Longitude     -122.220000
# Price            3.585000
# Name: 1, dtype: float64

# %%
#correlation -positive and negtive
#when one value increases other increases- positive

df2.corr()
# Out:
#               MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc      1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge   -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms    0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms  -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population  0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup    0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude   -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude  -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
# Price       0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
#
#             Latitude  Longitude     Price
# MedInc     -0.079809  -0.015176  0.688075
# HouseAge    0.011173  -0.108197  0.105623
# AveRooms    0.106389  -0.027540  0.151948
# AveBedrms   0.069721   0.013344 -0.046701
# ...
